# %%
pip install --upgrade matplotlib_inline matplotlib
# Out:
# Requirement already satisfied: matplotlib_inline in c:\users\34176\miniconda3\envs\d21\lib\site-packages (0.2.1)
# Requirement already satisfied: matplotlib in c:\users\34176\miniconda3\envs\d21\lib\site-packages (3.9.4)
# Requirement already satisfied: traitlets in c:\users\34176\miniconda3\envs\d21\lib\site-packages (from matplotlib_inline) (5.14.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\34176\miniconda3\envs\d21\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\34176\miniconda3\envs\d21\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\34176\miniconda3\envs\d21\lib\site-packages (from matplotlib) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\34176\miniconda3\envs\d21\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\34176\miniconda3\envs\d21\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\34176\miniconda3\envs\d21\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\34176\miniconda3\envs\d21\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\34176\miniconda3\envs\d21\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\34176\miniconda3\envs\d21\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\34176\miniconda3\envs\d21\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\34176\miniconda3\envs\d21\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\34176\miniconda3\envs\d21\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline
import numpy as np
from matplotlib_inline import backend_inline
from d2l import torch as d2l


def f(x):
    return 3 * x ** 2 - 4 * x
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import numpy as np
#       3 from matplotlib_inline import backend_inline
#
# File ~\miniconda3\envs\d21\lib\site-packages\IPython\core\interactiveshell.py:2456, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2454     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2455 with self.builtin_trap:
# -> 2456     result = fn(*args, **kwargs)
#    2458 # The code below prevents the output from being displayed
#    2459 # when using magics with decorator @output_can_be_silenced
#    2460 # when the last Python token in the expression is a ';'.
#    2461 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\miniconda3\envs\d21\lib\site-packages\IPython\core\magics\pylab.py:99, in PylabMagics.matplotlib(self, line)
#      97     print("Available matplotlib backends: %s" % backends_list)
#      98 else:
# ---> 99     gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100     self._show_matplotlib_backend(args.gui, backend)
#
# File ~\miniconda3\envs\d21\lib\site-packages\IPython\core\interactiveshell.py:3645, in InteractiveShell.enable_matplotlib(self, gui)
#    3641         print('Warning: Cannot change to a different GUI toolkit: %s.'
#    3642                 ' Using %s instead.' % (gui, self.pylab_gui_select))
#    3643         gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
# -> 3645 pt.activate_matplotlib(backend)
#    3646 configure_inline_support(self, backend)
#    3648 # Now we must activate the gui pylab wants to use, and fix %run to take
#    3649 # plot updates into account
#
# File ~\miniconda3\envs\d21\lib\site-packages\IPython\core\pylabtools.py:366, in activate_matplotlib(backend)
#     361 matplotlib.rcParams['backend'] = backend
#     363 # Due to circular imports, pyplot may be only partially initialised
#     364 # when this function runs.
#     365 # So avoid needing matplotlib attribute-lookup to access pyplot.
# --> 366 from matplotlib import pyplot as plt
#     368 plt.switch_backend(backend)
#     370 plt.show._needmain = False
#
# File ~\miniconda3\envs\d21\lib\site-packages\matplotlib\pyplot.py:73
#      71 from matplotlib import cm
#      72 from matplotlib.cm import _colormaps as colormaps, register_cmap
# ---> 73 from matplotlib.colors import _color_sequences as color_sequences
#      75 import numpy as np
#      77 # We may not need the following imports here:
#
# ImportError: cannot import name '_color_sequences' from 'matplotlib.colors' (C:\Users\34176\miniconda3\envs\d21\lib\site-packages\matplotlib\colors.py)
# Error in callback <function _enable_matplotlib_integration.<locals>.configure_once at 0x00000173A05FE940> (for post_run_cell), with arguments args (<ExecutionResult object at 173a05efeb0, execution_count=24 error_before_exec=None error_in_exec=cannot import name '_color_sequences' from 'matplotlib.colors' (C:\Users\34176\miniconda3\envs\d21\lib\site-packages\matplotlib\colors.py) info=<ExecutionInfo object at 173a03fca30, raw_cell="%matplotlib inline
# import numpy as np
# from matplot.." store_history=True silent=False shell_futures=True cell_id=None> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\miniconda3\envs\d21\lib\site-packages\matplotlib_inline\backend_inline.py:222, in _enable_matplotlib_integration.<locals>.configure_once(*args)
#     221 def configure_once(*args):
# --> 222     activate_matplotlib(backend)
#     223     configure_inline_support(ip, backend)
#     224     ip.events.unregister('post_run_cell', configure_once)
#
# File ~\miniconda3\envs\d21\lib\site-packages\IPython\core\pylabtools.py:366, in activate_matplotlib(backend)
#     361 matplotlib.rcParams['backend'] = backend
#     363 # Due to circular imports, pyplot may be only partially initialised
#     364 # when this function runs.
#     365 # So avoid needing matplotlib attribute-lookup to access pyplot.
# --> 366 from matplotlib import pyplot as plt
#     368 plt.switch_backend(backend)
#     370 plt.show._needmain = False
#
# File ~\miniconda3\envs\d21\lib\site-packages\matplotlib\pyplot.py:73
#      71 from matplotlib import cm
#      72 from matplotlib.cm import _colormaps as colormaps, register_cmap
# ---> 73 from matplotlib.colors import _color_sequences as color_sequences
#      75 import numpy as np
#      77 # We may not need the following imports here:
#
# ImportError: cannot import name '_color_sequences' from 'matplotlib.colors' (C:\Users\34176\miniconda3\envs\d21\lib\site-packages\matplotlib\colors.py)
